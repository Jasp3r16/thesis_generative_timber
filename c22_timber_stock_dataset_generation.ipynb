# %% [markdown]
# # Thesis: Reclaimed Timber in Deep Generative Design
# **Notebook ID:** 23_timber_stock_dataset_generation
# **Author:** Jasper Cluistra
# **Last Updated:** 2026-03-19
# ### Timber stock dataset generation script
# **Goal:** Generate the timber stock datasets that the algorithm can use to choose elements for the design.
#
# **Inputs:**
# *   Parameters for stock properties
#
# **Outputs:**
# *   CSV file with datasets for new stock and reclaimed stock

# %% [markdown]
# # STOCK GENERATION

# %%
import pandas as pd
import config
from c22_generation_timber import generate_new_stock, generate_reclaimed_stock

# GENERATE NEW STOCK
df_new_stock = generate_new_stock()
display(df_new_stock.head(3))

# GENERATE RECLAIMED STOCK
df_reclaimed_stock = generate_reclaimed_stock()
display(df_reclaimed_stock.head(3))
# Out:
# System loaded successfully.
#
# Code is running locally from: thesis_generative_timber
# Data connected to OneDrive: 2.2 - 2.4
#
# GH data directory: C:\Users\jaspe\OneDrive\06 Building Technology TU\2.2 - 2.4\30_Data_Inventory\01_grasshopper_data
# Raw data directory: C:\Users\jaspe\OneDrive\06 Building Technology TU\2.2 - 2.4\30_Data_Inventory\02_raw_data
# Export directory: C:\Users\jaspe\OneDrive\06 Building Technology TU\2.2 - 2.4\60_Research_Exports
#
# Generating catalog... 442 beam types
# Generated length tuple (mm): (1450, 1750, 2050, 2350, 2650, 2950, 3250, 3550, 3850, 4150, 4450, 4750, 5050), with average used: 2944.3997535418384
# New stock generated successfully! (442 elements)
#   Member_ID  State  Length  Depth  Width  f_mk  f_tk  E_modulus_eff  \
# 0  NS_00000      0  1450.0  100.0   38.0  24.0  14.0        11000.0
# 1  NS_00001      0  1450.0  100.0   50.0  24.0  14.0        11000.0
# 2  NS_00002      0  1450.0  100.0   63.0  24.0  14.0        11000.0
#
#    E_modulus_005  f_vk  f_c0k  k_density  mean_density    ECC Origin_Country  \
# 0         7400.0   2.5   21.0      350.0         420.0  150.0  Baltic States
# 1         7400.0   2.5   21.0      350.0         420.0  150.0         France
# 2         7400.0   2.5   21.0      350.0         420.0  150.0        Germany
#
#    Transport_Dist  EmissionFactor  ProcessingFactor
# 0         1558.51          0.1765                 0
# 1          462.42          0.1726                 0
# 2          335.57          0.1749                 0
# Reclaimed length range (mm): 2650 to 4200
# Reclaimed stock generated successfully! (38 elements)
#   Member_ID  State  Length  Depth  Width  f_mk  f_tk  E_modulus_eff  \
# 0  RS_00001      1  3500.0  150.0   50.0  18.0  11.0         9000.0
# 1  RS_00002      1  2750.0  170.0   60.0  18.0  11.0         9000.0
# 2  RS_00003      1  3050.0  230.0   70.0  18.0  11.0         9000.0
#
#    E_modulus_005  f_vk  f_c0k  k_density  mean_density  ECC Origin_Country  \
# 0         6000.0   2.0   18.0      320.0         380.0  0.0    Netherlands
# 1         6000.0   2.0   18.0      320.0         380.0  0.0    Netherlands
# 2         6000.0   2.0   18.0      320.0         380.0  0.0    Netherlands
#
#    Transport_Dist  EmissionFactor  ProcessingFactor
# 0              31          0.1732                 1
# 1             135          0.1788                 1
# 2             129          0.0283                 1

# %%
# TABLE WITH DEPTH AND WIDTH
print("\n" + "="*50)
print("TABLE: ALL DEPTH AND WIDTH COMBINATIONS")
print("="*50)

depth_width_combinations = df_new_stock[['Depth', 'Width']].drop_duplicates().sort_values(by=['Depth', 'Width']).reset_index(drop=True)

print(f"\n{'Basic size':<15} {'D (mm)':<12} {'W (mm)':<12}")
print("-" * 40)

for idx, (_, row) in enumerate(depth_width_combinations.iterrows(), 1):
    depth = int(row['Depth'])
    width = int(row['Width'])
    print(f"{idx:<15} {depth:<12} {width:<12}")

print("-" * 40)
print(f"Total number of combinations: {len(depth_width_combinations)}")

# depth_width_combinations.to_csv('depth_width_combinations.csv', index=False)
# print("\nExported to 'depth_width_combinations.csv'")
# Out:
# ==================================================
# TABLE: ALL DEPTH AND WIDTH COMBINATIONS
# ==================================================
#
# Basic size      D (mm)       W (mm)
# ----------------------------------------
# 1               100          38
# 2               100          50
# 3               100          63
# 4               100          75
# 5               100          100
# 6               150          38
# 7               150          50
# 8               150          63
# 9               150          75
# 10              150          100
# 11              175          38
# 12              175          50
# 13              175          63
# 14              175          75
# 15              200          38
# 16              200          50
# 17              200          63
# 18              200          75
# 19              200          100
# 20              200          150
# 21              200          200
# 22              225          38
# 23              225          50
# 24              225          63
# 25              225          75
# 26              250          50
# 27              250          75
# 28              250          100
# 29              250          250
# 30              300          50
# 31              300          75
# 32              300          100
# 33              300          150
# 34              300          300
# ----------------------------------------
# Total number of combinations: 34

# %% [markdown]
# # EXPORTING

# %%
import config
from c22_generation_timber import generate_mixed_stock_subset
# Combine both datasets into one large matrix
df_combined_stock = pd.concat([df_new_stock, df_reclaimed_stock], ignore_index=True)

# Show a random selection from the combined dataset
print("\nPreview of the combined inventory (mix of NS and RS):")
display(df_combined_stock.sample(6))

# Export
dataset_filename = 'complete_timber.csv'
df_combined_stock.to_csv(config.TIMBER_STOCK_PATH / dataset_filename, index=False, sep=';')

print(f"\nEverything was successfully combined and saved as '{dataset_filename}'.")

# Generate a smaller subset for testing purposes
df_small = generate_mixed_stock_subset(
    total_elements=20,
    reclaimed_ratio=0.3,
    random_state=38,
    allow_replacement=True
)

display(df_small.head(5))
dataset_filename = 'complete_timber_small.csv'
df_small.to_csv(config.TIMBER_STOCK_PATH / dataset_filename, index=False)
# Out:
# Preview of the combined inventory (mix of NS and RS):
#     Member_ID  State  Length  Depth  Width  f_mk  f_tk  E_modulus_eff  \
# 33   NS_00033      0  1450.0  300.0  300.0  24.0  14.0        11000.0
# 271  NS_00271      0  3550.0  300.0  300.0  24.0  14.0        11000.0
# 146  NS_00146      0  2650.0  175.0   38.0  24.0  14.0        11000.0
# 58   NS_00058      0  1750.0  225.0   75.0  24.0  14.0        11000.0
# 298  NS_00298      0  3850.0  250.0   75.0  24.0  14.0        11000.0
# 311  NS_00311      0  4150.0  150.0   38.0  24.0  14.0        11000.0
#
#      E_modulus_005  f_vk  f_c0k  k_density  mean_density    ECC  \
# 33          7400.0   2.5   21.0      350.0         420.0  150.0
# 271         7400.0   2.5   21.0      350.0         420.0  150.0
# 146         7400.0   2.5   21.0      350.0         420.0  150.0
# 58          7400.0   2.5   21.0      350.0         420.0  150.0
# 298         7400.0   2.5   21.0      350.0         420.0  150.0
# 311         7400.0   2.5   21.0      350.0         420.0  150.0
#
#     Origin_Country  Transport_Dist  EmissionFactor  ProcessingFactor
# 33   Baltic States         1321.38          0.1716                 0
# 271  Baltic States         1404.15          0.1709                 0
# 146         Sweden         1005.76          0.1722                 0
# 58         Finland         1644.06          0.1732                 0
# 298          Other         4134.64          0.1768                 0
# 311         France          480.94          0.1768                 0
# Everything was successfully combined and saved as 'complete_timber.csv'.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 17
#      14 print(f"\nEverything was successfully combined and saved as '{dataset_filename}'.")
#      16 # Generate a smaller subset for testing purposes
# ---> 17 df_small = generate_mixed_stock_subset(
#      18     total_elements=20,
#      19     reclaimed_ratio=0.3,
#      20     random_state=38,
#      21     allow_replacement=True
#      22 )
#      24 display(df_small.head(5))
#      25 dataset_filename = 'complete_timber_small.csv'
#
# File ~\Documents\PyRepo\thesis_generative_timber\src\c22_generation_timber.py:321, in generate_mixed_stock_subset(total_elements, reclaimed_ratio, random_state, allow_replacement)
#     318 requested_reclaimed = int(round(total_elements * reclaimed_ratio))
#     319 requested_new = total_elements - requested_reclaimed
# --> 321 df_new = generate_new_timber_catalog()
#     322 df_reclaimed = generate_reclaimed_stock()
#     324 available_new = len(df_new)
#
# NameError: name 'generate_new_timber_catalog' is not defined
