# %% [markdown]
# # Thesis: Reclaimed Timber in Deep Generative Design
# **Notebook ID:** c22_timber_stock_dataset_generation
# **Author:** Jasper Cluistra
# **Last Updated:** 2026-04-21
# ### Timber stock dataset generation script
# **Goal:** Generate the timber stock datasets that the algorithm can use to choose elements for the design.
#
# **Inputs:**
# *   Parameters for stock properties
#
# **Outputs:**
# *   CSV file with datasets for new stock and reclaimed stock

# %% [markdown]
# # STOCK GENERATION

# %%
import pandas as pd
import config
from c22_generation_timber import generate_new_stock, generate_reclaimed_stock

efficient = True  # Set to True for efficient transport distances, False for realistic distances

# GENERATE NEW STOCK
df_new_stock = generate_new_stock(efficient)
display(df_new_stock.head(3))

# GENERATE RECLAIMED STOCK
df_reclaimed_stock = generate_reclaimed_stock()
display(df_reclaimed_stock.head(3))

# Combine both datasets into one large matrix
df_combined_stock = pd.concat([df_new_stock, df_reclaimed_stock], ignore_index=True)

# Show a random selection from the combined dataset
print("\nPreview of the combined inventory (mix of NS and RS):")
display(df_combined_stock.sample(6))

# Export
new_stock_dataset_filename = 'new_timber.csv'
df_new_stock.to_csv(config.TIMBER_STOCK_PATH / new_stock_dataset_filename, index=False, sep=';')
combined_dataset_filename = 'complete_timber.csv'
df_combined_stock.to_csv(config.TIMBER_STOCK_PATH / combined_dataset_filename, index=False, sep=';')

print(f"New stock dataset saved as '{new_stock_dataset_filename}'.")
print(f"Combined dataset saved as '{combined_dataset_filename}'.")
# Out:
# System loaded successfully.
#
# Code is running locally from: thesis_generative_timber
# Data connected to OneDrive: 2.2 - 2.4
#
# GH data directory: C:\Users\jaspe\OneDrive\06 Building Technology TU\2.2 - 2.4\30_Data_Inventory\02_grasshopper_data
# Geometry data directory: C:\Users\jaspe\OneDrive\06 Building Technology TU\2.2 - 2.4\30_Data_Inventory\01_geometry_data
# Export directory: C:\Users\jaspe\OneDrive\06 Building Technology TU\2.2 - 2.4\60_Research_Exports
#
# Generating catalog... 442 beam types
# Generated length tuple (mm): (1450, 1750, 2050, 2350, 2650, 2950, 3250, 3550, 3850, 4150, 4450, 4750, 5050), with average used: 2935.594108376189
# New stock generated successfully! (442 elements)
#   Member_ID  State  Length  Depth  Width  f_mk  f_tk  E_modulus_eff  \
# 0  NS_00000      0  1450.0  100.0   38.0  24.0  14.0        11000.0
# 1  NS_00001      0  1450.0  100.0   50.0  24.0  14.0        11000.0
# 2  NS_00002      0  1450.0  100.0   63.0  24.0  14.0        11000.0
#
#    E_modulus_005  f_vk  f_c0k  k_density  mean_density Origin_Country  \
# 0         7400.0   2.5   21.0      350.0         420.0    Netherlands
# 1         7400.0   2.5   21.0      350.0         420.0        Germany
# 2         7400.0   2.5   21.0      350.0         420.0        Germany
#
#    Transport_Dist  EmissionFactor
# 0           44.30          0.1745
# 1          272.26          0.1702
# 2          299.52          0.1756
# Reclaimed length range (mm): 2250 to 4350
# Reclaimed stock generated successfully! (38 elements)
#   Member_ID  State  Length  Depth  Width  f_mk  f_tk  E_modulus_eff  \
# 0  RS_00001      1  2600.0  150.0   50.0  18.0  11.0         9000.0
# 1  RS_00002      1  3000.0  170.0   60.0  18.0  11.0         9000.0
# 2  RS_00003      1  4350.0  230.0   70.0  18.0  11.0         9000.0
#
#    E_modulus_005  f_vk  f_c0k  k_density  mean_density Origin_Country  \
# 0         6000.0   2.0   18.0      320.0         380.0    Netherlands
# 1         6000.0   2.0   18.0      320.0         380.0    Netherlands
# 2         6000.0   2.0   18.0      320.0         380.0    Netherlands
#
#    Transport_Dist  EmissionFactor
# 0             204          0.1784
# 1              30          0.1763
# 2             175          0.0336
# Preview of the combined inventory (mix of NS and RS):
#     Member_ID  State  Length  Depth  Width  f_mk  f_tk  E_modulus_eff  \
# 275  NS_00275      0  3850.0  100.0   75.0  24.0  14.0        11000.0
# 49   NS_00049      0  1750.0  200.0   50.0  24.0  14.0        11000.0
# 367  NS_00367      0  4450.0  250.0  100.0  24.0  14.0        11000.0
# 238  NS_00238      0  3550.0  100.0   38.0  24.0  14.0        11000.0
# 56   NS_00056      0  1750.0  225.0   50.0  24.0  14.0        11000.0
# 222  NS_00222      0  3250.0  200.0  100.0  24.0  14.0        11000.0
#
#      E_modulus_005  f_vk  f_c0k  k_density  mean_density Origin_Country  \
# 275         7400.0   2.5   21.0      350.0         420.0    Netherlands
# 49          7400.0   2.5   21.0      350.0         420.0        Germany
# 367         7400.0   2.5   21.0      350.0         420.0    Netherlands
# 238         7400.0   2.5   21.0      350.0         420.0    Netherlands
# 56          7400.0   2.5   21.0      350.0         420.0        Germany
# 222         7400.0   2.5   21.0      350.0         420.0    Netherlands
#
#      Transport_Dist  EmissionFactor
# 275           49.80          0.1790
# 49           298.90          0.1762
# 367           50.94          0.1770
# 238           45.41          0.1796
# 56           340.12          0.1705
# 222           48.15          0.1792
# New stock dataset saved as 'new_timber.csv'.
# Combined dataset saved as 'complete_timber.csv'.

# %% [markdown]
# ## CHECK COMBINATIONS

# %%
# TABLE WITH DEPTH AND WIDTH
print("\n" + "="*50)
print("TABLE: ALL DEPTH AND WIDTH COMBINATIONS")
print("="*50)

depth_width_combinations = df_new_stock[['Depth', 'Width']].drop_duplicates().sort_values(by=['Depth', 'Width']).reset_index(drop=True)

print(f"\n{'Basic size':<15} {'D (mm)':<12} {'W (mm)':<12}")
print("-" * 40)

for idx, (_, row) in enumerate(depth_width_combinations.iterrows(), 1):
    depth = int(row['Depth'])
    width = int(row['Width'])
    print(f"{idx:<15} {depth:<12} {width:<12}")

print("-" * 40)
print(f"Total number of combinations: {len(depth_width_combinations)}")

# depth_width_combinations.to_csv('depth_width_combinations.csv', index=False)
# print("\nExported to 'depth_width_combinations.csv'")
# Out:
# ==================================================
# TABLE: ALL DEPTH AND WIDTH COMBINATIONS
# ==================================================
#
# Basic size      D (mm)       W (mm)
# ----------------------------------------
# 1               100          38
# 2               100          50
# 3               100          63
# 4               100          75
# 5               100          100
# 6               150          38
# 7               150          50
# 8               150          63
# 9               150          75
# 10              150          100
# 11              175          38
# 12              175          50
# 13              175          63
# 14              175          75
# 15              200          38
# 16              200          50
# 17              200          63
# 18              200          75
# 19              200          100
# 20              200          150
# 21              200          200
# 22              225          38
# 23              225          50
# 24              225          63
# 25              225          75
# 26              250          50
# 27              250          75
# 28              250          100
# 29              250          250
# 30              300          50
# 31              300          75
# 32              300          100
# 33              300          150
# 34              300          300
# ----------------------------------------
# Total number of combinations: 34

# %% [markdown]
# ## SUBSET

# %%
import config
from c22_generation_timber import generate_mixed_stock_subset

# Generate a smaller subset for testing purposes
df_small = generate_mixed_stock_subset(
    total_elements=20,
    reclaimed_ratio=0.3,
    random_state=38,
    allow_replacement=True
)

display(df_small.head(5))
dataset_filename = 'complete_timber_small.csv'
df_small.to_csv(config.TIMBER_STOCK_PATH / dataset_filename, index=False)
# Out:
# Generating catalog... 442 beam types
# Generated length tuple (mm): (1450, 1750, 2050, 2350, 2650, 2950, 3250, 3550, 3850, 4150, 4450, 4750, 5050), with average used: 2935.594108376189
# New stock generated successfully! (442 elements)
# Reclaimed length range (mm): 2350 to 4150
# Reclaimed stock generated successfully! (38 elements)
# Mixed subset generated: 20 total | new=14, reclaimed=6 (reclaimed_ratio=0.30)
#   Member_ID  State  Length  Depth  Width  f_mk  f_tk  E_modulus_eff  \
# 0  NS_00038      0  1750.0  100.0  100.0  24.0  14.0        11000.0
# 1  NS_00241      0  3550.0  100.0   75.0  24.0  14.0        11000.0
# 2  NS_00002      0  1450.0  100.0   63.0  24.0  14.0        11000.0
# 3  NS_00050      0  1750.0  200.0   63.0  24.0  14.0        11000.0
# 4  NS_00151      0  2650.0  200.0   50.0  24.0  14.0        11000.0
#
#    E_modulus_005  f_vk  f_c0k  k_density  mean_density Origin_Country  \
# 0         7400.0   2.5   21.0      350.0         420.0        Germany
# 1         7400.0   2.5   21.0      350.0         420.0          Other
# 2         7400.0   2.5   21.0      350.0         420.0         Poland
# 3         7400.0   2.5   21.0      350.0         420.0        Germany
# 4         7400.0   2.5   21.0      350.0         420.0        Finland
#
#    Transport_Dist  EmissionFactor
# 0          321.61          0.1785
# 1         4424.44          0.1765
# 2          849.82          0.1786
# 3          307.37          0.1777
# 4         2060.13          0.1764
