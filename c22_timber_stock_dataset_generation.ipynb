# %% [markdown]
# # Thesis: Reclaimed Timber in Deep Generative Design
# **Notebook ID:** 23_timber_stock_dataset_generation
# **Author:** Jasper Cluistra
# **Last Updated:** 2026-03-19
# ### Properties script
# **Goal:** to generate the timber stock datasets, that the algorithm can use to choose elements for the design
#
# **Inputs:**
# *   parameters for properties of the stock
#
# **Outputs:**
# *   CSV file with dataset of new stock and reused stock

# %% [markdown]
# # GENERATION

# %%
# ==========================================
# GENERATIE NEW STOCK
# ==========================================
import pandas as pd
import config
from generation_timber import generate_new_timber_catalog, generate_reclaimed_stock

df_new_stock = generate_new_timber_catalog()
display(df_new_stock.head(3))

# ==========================================
# GENERATIE RECLAIMED STOCK
# ==========================================
df_reused_stock = generate_reclaimed_stock()
display(df_reused_stock.head(3))
# Out:
# ✅ Systeem succesvol geladen.
# 📂 Code draait lokaal vanuit: thesis_generative_timber
# ☁️ Data gekoppeld aan OneDrive: 2.2 - 2.4
# Gegenereerde lengte tuple (mm): (1500, 1800, 2100, 2400, 2700, 3000, 3300, 3600, 3900)
# 📊 Catalogus genereren... 306 balk-typen
# ✅ New stock succesvol gegenereerd! (306 elementen)
#   Member_ID  State  Length  Depth  Width  f_mk  E_modulus_eff  E_modulus_005  \
# 0  NS_00000      0  1500.0  100.0   38.0  24.0        11000.0         7400.0
# 1  NS_00001      0  1500.0  100.0   50.0  24.0        11000.0         7400.0
# 2  NS_00002      0  1500.0  100.0   63.0  24.0        11000.0         7400.0
#
#    f_vk  f_c0k  k_density  mean_density    ECC Origin_Country  Transport_Dist  \
# 0   2.5   21.0      350.0         420.0  150.0      Nederland           45.41
# 1   2.5   21.0      350.0         420.0  150.0         Overig         3582.82
# 2   2.5   21.0      350.0         420.0  150.0      Duitsland          317.32
#
#    Emmisiefactor  Bewerkingsfactor
# 0         0.1724                 0
# 1         0.1739                 0
# 2         0.1748                 0
# ✅ Reclaimed stock gegenereerd! (18 elementen)
#   Member_ID  State  Length  Depth  Width  f_mk  E_modulus_eff  E_modulus_005  \
# 0  RS_00001      1  3700.0  150.0   50.0  18.0         9000.0         6000.0
# 1  RS_00002      1  4100.0  170.0   60.0  18.0         9000.0         6000.0
# 2  RS_00003      1  3200.0  230.0   70.0  18.0         9000.0         6000.0
#
#    f_vk  f_c0k  k_density  mean_density  ECC Origin_Country  Transport_Dist  \
# 0   2.0   18.0      320.0         380.0  0.0    Netherlands              93
# 1   2.0   18.0      320.0         380.0  0.0    Netherlands             222
# 2   2.0   18.0      320.0         380.0  0.0    Netherlands               8
#
#    Emmisiefactor  Bewerkingsfactor
# 0         0.0351                 1
# 1         0.0424                 1
# 2         0.1790                 1

# %%
# ==========================================
# TABEL MET DEPTH EN WIDTH
# ==========================================
print("\n" + "="*50)
print("📊 TABEL: ALLE DIEPTE EN BREEDTE COMBINATIES")
print("="*50)

depth_width_combinations = df_new_stock[['Depth', 'Width']].drop_duplicates().sort_values(by=['Depth', 'Width']).reset_index(drop=True)

print(f"\n{'Basic size':<15} {'D (mm)':<12} {'B (mm)':<12}")
print("-" * 40)

for idx, (_, row) in enumerate(depth_width_combinations.iterrows(), 1):
    depth = int(row['Depth'])
    width = int(row['Width'])
    print(f"{idx:<15} {depth:<12} {width:<12}")

print("-" * 40)
print(f"Totaal aantal combinaties: {len(depth_width_combinations)}")

# depth_width_combinations.to_csv('depth_width_combinations.csv', index=False)
# print("\n✅ Geëxporteerd naar 'depth_width_combinations.csv'")
# Out:
# ==================================================
# 📊 TABEL: ALLE DIEPTE EN BREEDTE COMBINATIES
# ==================================================
#
# Basic size      D (mm)       B (mm)
# ----------------------------------------
# 1               100          38
# 2               100          50
# 3               100          63
# 4               100          75
# 5               100          100
# 6               150          38
# 7               150          50
# 8               150          63
# 9               150          75
# 10              150          100
# 11              175          38
# 12              175          50
# 13              175          63
# 14              175          75
# 15              200          38
# 16              200          50
# 17              200          63
# 18              200          75
# 19              200          100
# 20              200          150
# 21              200          200
# 22              225          38
# 23              225          50
# 24              225          63
# 25              225          75
# 26              250          50
# 27              250          75
# 28              250          100
# 29              250          250
# 30              300          50
# 31              300          75
# 32              300          100
# 33              300          150
# 34              300          300
# ----------------------------------------
# Totaal aantal combinaties: 34

# %% [markdown]
# # EXPORTING

# %%
import config
# Voeg beide datasets samen tot één grote matrix
df_combined_stock = pd.concat([df_new_stock, df_reused_stock], ignore_index=True)

# Toon een willekeurige selectie uit de gecombineerde dataset
print("\nPreview van de gecombineerde inventaris (mix van NS en RS):")
display(df_combined_stock.sample(6))

# Exporteren
dataset_filename = 'complete_timber.csv'
df_combined_stock.to_csv(config.TIMBER_STOCK_PATH / dataset_filename, index=False, sep=';')
# df_combined_stock.to_csv(dataset_filename, index=False, sep=';')

print(f"\nAlles succesvol samengevoegd en opgeslagen als '{dataset_filename}'.")
# Out:
# Preview van de gecombineerde inventaris (mix van NS en RS):
#     Member_ID  State  Length  Depth  Width  f_mk  E_modulus_eff  \
# 276  NS_00276      0  3900.0  100.0  100.0  24.0        11000.0
# 315  RS_00010      1  3050.0  170.0   60.0  18.0         9000.0
# 37   NS_00037      0  1800.0  100.0   75.0  24.0        11000.0
# 94   NS_00094      0  2100.0  250.0   75.0  24.0        11000.0
# 108  NS_00108      0  2400.0  150.0   50.0  24.0        11000.0
# 271  NS_00271      0  3600.0  300.0  300.0  24.0        11000.0
#
#      E_modulus_005  f_vk  f_c0k  k_density  mean_density    ECC  \
# 276         7400.0   2.5   21.0      350.0         420.0  150.0
# 315         6000.0   2.0   18.0      320.0         380.0    0.0
# 37          7400.0   2.5   21.0      350.0         420.0  150.0
# 94          7400.0   2.5   21.0      350.0         420.0  150.0
# 108         7400.0   2.5   21.0      350.0         420.0  150.0
# 271         7400.0   2.5   21.0      350.0         420.0  150.0
#
#        Origin_Country  Transport_Dist  Emmisiefactor  Bewerkingsfactor
# 276            Overig         3468.91         0.1713                 0
# 315       Netherlands          181.00         0.1702                 1
# 37              Polen          779.70         0.1726                 0
# 94   Baltische Staten         1574.43         0.1768                 0
# 108            België          134.95         0.1704                 0
# 271         Duitsland          331.77         0.1777                 0
# Alles succesvol samengevoegd en opgeslagen als 'complete_timber.csv'.

# %% [markdown]
# # DATASET SMALL
# for testing of the workflow with smaller structure in a controlled environment

# %%
import config
from generation_timber import generate_mixed_stock_subset

df_small = generate_mixed_stock_subset(
    total_elements=20, 
    reused_ratio=0.3, 
    random_state=38,
    allow_replacement=True
)

display(df_small.head(5))

dataset_filename = 'complete_timber_small.csv'
df_small.to_csv(config.TIMBER_STOCK_PATH / dataset_filename, index=False)
# Out:
# 📊 Catalogus genereren... 306 balk-typen
# ✅ New stock succesvol gegenereerd! (306 elementen)
# ✅ Reclaimed stock gegenereerd! (18 elementen)
# 📦 Mixed subset gegenereerd: 20 totaal | new=14, reused=6 (reused_ratio=0.30)
#   Member_ID  State  Length  Depth  Width  f_mk  E_modulus_eff  E_modulus_005  \
# 0  NS_00069      0  2100.0  100.0   50.0  24.0        11000.0         7400.0
# 1  NS_00203      0  3000.0  300.0  300.0  24.0        11000.0         7400.0
# 2  NS_00009      0  1500.0  150.0  100.0  24.0        11000.0         7400.0
# 3  NS_00027      0  1500.0  250.0  100.0  24.0        11000.0         7400.0
# 4  NS_00164      0  2700.0  250.0  250.0  24.0        11000.0         7400.0
#
#    f_vk  f_c0k  k_density  mean_density    ECC    Origin_Country  \
# 0   2.5   21.0      350.0         420.0  150.0            Zweden
# 1   2.5   21.0      350.0         420.0  150.0            Overig
# 2   2.5   21.0      350.0         420.0  150.0  Baltische Staten
# 3   2.5   21.0      350.0         420.0  150.0             Polen
# 4   2.5   21.0      350.0         420.0  150.0         Duitsland
#
#    Transport_Dist  Emmisiefactor  Bewerkingsfactor
# 0          970.63         0.1738                 0
# 1         3873.51         0.1763                 0
# 2         1517.42         0.1752                 0
# 3          936.13         0.1717                 0
# 4          288.38         0.1717                 0
