# %% [markdown]
# # Thesis: Reclaimed Timber in Deep Generative Design
# **Notebook ID:** master_template
# **Author:** Jasper Cluistra
# **Last Updated:** 20YY-MM-DD
# ### Properties script
# **Goal:** XXX
# **Inputs:**
# *   Lijstitem
# *   Lijstitem
#
# **Outputs:**
# *   Lijstitem
# *   Lijstitem

# %% [markdown]
# # IMPORT

# %% [markdown]
# # SURROGATE MODEL CHECK

# %% [markdown]
# # BUCKLING CHECK
